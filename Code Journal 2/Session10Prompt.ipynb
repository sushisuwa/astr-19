# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
n = 1000
x = np.random.power(1,n)

f, ax = plt.subplots(1,1,figsize=(4,4))

ax.hist(x,bins=100,edgecolor='black',alpha=1.0)
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.savefig('s10.pdf',bbox_inches='tight',dpi=600)
